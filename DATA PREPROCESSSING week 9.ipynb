# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Nagendra Swamy/Desktop/NoCodeAi/city_day.csv")
df
# Out:
#                 City       Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad   1/1/2015    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad   1/2/2015    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad   1/3/2015    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad   1/4/2015    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad   1/5/2015    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...        ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  6/27/2020  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  6/28/2020  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  6/29/2020  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  6/30/2020  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam   7/1/2020  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# ...

# %%
plt.figure(figsize=(8, 4), dpi=200)
palette = {'Good': "g", 'Poor': "C0", 'Very Poor': "C1", 'Severe': "r", "Moderate": 'b', "Satisfactory": 'y'}
sns.scatterplot(x='AQI', y='PM2.5', data=df, hue='AQI_Bucket', palette=palette, ci=None)
plt.show()

# %%
df = df.drop(columns=["AQI_Bucket", "NH3"])
df
# Out:
#                 City       Date  PM2.5   PM10     NO    NO2    NOx     CO  \
# 0          Ahmedabad   1/1/2015    NaN    NaN   0.92  18.22  17.15   0.92
# 1          Ahmedabad   1/2/2015    NaN    NaN   0.97  15.69  16.46   0.97
# 2          Ahmedabad   1/3/2015    NaN    NaN  17.40  19.30  29.70  17.40
# 3          Ahmedabad   1/4/2015    NaN    NaN   1.70  18.48  17.97   1.70
# 4          Ahmedabad   1/5/2015    NaN    NaN  22.10  21.42  37.76  22.10
# ...              ...        ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  6/27/2020  15.02  50.94   7.68  25.06  19.54   0.47
# 29527  Visakhapatnam  6/28/2020  24.38  74.09   3.42  26.06  16.53   0.52
# 29528  Visakhapatnam  6/29/2020  22.91  65.73   3.45  29.53  18.33   0.48
# 29529  Visakhapatnam  6/30/2020  16.64  49.97   4.05  29.26  18.80   0.52
# 29530  Visakhapatnam   7/1/2020  15.00  66.00   0.40  26.85  14.05   0.59
#
#          SO2      O3  Benzene  Toluene  Xylene   AQI
# ...

# %%
df = df[1098:3073]
df
# Out:
#            City       Date  PM2.5   PM10     NO     NO2     NOx     CO  \
# 1098  Ahmedabad   1/3/2018  63.88    NaN  13.87   69.32   44.16  13.87
# 1099  Ahmedabad   1/4/2018  81.10    NaN  19.42  109.07   67.15  19.42
# 1100  Ahmedabad   1/5/2018  73.61    NaN  25.96  173.08  103.80  25.96
# 1101  Ahmedabad   1/6/2018  75.79    NaN  31.55  146.80   95.16  31.55
# 1102  Ahmedabad   1/7/2018  77.87    NaN  23.19  137.62   84.44  23.19
# ...         ...        ...    ...    ...    ...     ...     ...    ...
# 3068  Amaravati  6/27/2020  14.50  24.43   1.53    6.53    4.72   0.55
# 3069  Amaravati  6/28/2020  16.65  28.51   1.43    8.32    5.59   0.66
# 3070  Amaravati  6/29/2020  20.96  32.56   1.65    9.55    6.43   0.66
# 3071  Amaravati  6/30/2020  21.34  35.16   1.74   10.69    7.10   0.66
# 3072  Amaravati   7/1/2020  22.00  34.00   1.50    9.68    6.40   0.59
#
#          SO2      O3  Benzene  Toluene  Xylene    AQI
# 1098   70.30  105.33    12.77    60.99    9.50  300.0
# ...

# %%
df.head()
# Out:
#            City      Date  PM2.5  PM10     NO     NO2     NOx     CO     SO2  \
# 1098  Ahmedabad  1/3/2018  63.88   NaN  13.87   69.32   44.16  13.87   70.30
# 1099  Ahmedabad  1/4/2018  81.10   NaN  19.42  109.07   67.15  19.42   93.30
# 1100  Ahmedabad  1/5/2018  73.61   NaN  25.96  173.08  103.80  25.96   93.86
# 1101  Ahmedabad  1/6/2018  75.79   NaN  31.55  146.80   95.16  31.55  113.82
# 1102  Ahmedabad  1/7/2018  77.87   NaN  23.19  137.62   84.44  23.19  107.58
#
#           O3  Benzene  Toluene  Xylene    AQI
# 1098  105.33    12.77    60.99    9.50  300.0
# 1099   65.69    19.56    72.46   11.29  532.0
# 1100   36.51    17.69    61.48    9.93  534.0
# 1101   41.95    21.18    64.94   11.11  738.0
# 1102   50.46    16.52    56.80   10.21  622.0

# %%
df.tail()
# Out:
#            City       Date  PM2.5   PM10    NO    NO2   NOx    CO    SO2  \
# 3068  Amaravati  6/27/2020  14.50  24.43  1.53   6.53  4.72  0.55  13.75
# 3069  Amaravati  6/28/2020  16.65  28.51  1.43   8.32  5.59  0.66  10.86
# 3070  Amaravati  6/29/2020  20.96  32.56  1.65   9.55  6.43  0.66  14.79
# 3071  Amaravati  6/30/2020  21.34  35.16  1.74  10.69  7.10  0.66  14.58
# 3072  Amaravati   7/1/2020  22.00  34.00  1.50   9.68  6.40  0.59  10.88
#
#          O3  Benzene  Toluene  Xylene   AQI
# 3068  33.76     0.06     0.27    0.15  42.0
# 3069  37.34     0.10     0.43    0.12  49.0
# 3070  43.29     0.12     0.69    0.10  56.0
# 3071  45.32     0.14     1.42    0.20  61.0
# 3072  29.15     0.10     0.50     NaN  54.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1975 entries, 1098 to 3072
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     1975 non-null   object
#  1   Date     1975 non-null   object
#  2   PM2.5    1905 non-null   float64
#  3   PM10     1415 non-null   float64
#  4   NO       1912 non-null   float64
#  5   NO2      1912 non-null   float64
#  6   NOx      1916 non-null   float64
#  7   CO       1870 non-null   float64
#  8   SO2      1870 non-null   float64
#  9   O3       1833 non-null   float64
#  10  Benzene  1850 non-null   float64
#  11  Toluene  1850 non-null   float64
#  12  Xylene   1557 non-null   float64
#  13  AQI      1835 non-null   float64
# dtypes: float64(12), object(2)
# memory usage: 216.1+ KB

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1905.000000  1415.000000  1912.000000  1912.000000  1916.000000
# mean     48.679848    83.160134    14.860805    46.533217    33.389311
# std      33.579316    49.386956    18.137946    45.873499    32.461543
# min       0.160000     1.150000     0.250000     0.050000     0.000000
# 25%      22.900000    44.090000     3.087500    13.107500    10.392500
# 50%      40.980000    76.610000     7.095000    28.270000    20.110000
# 75%      68.760000   115.415000    20.837500    68.997500    48.872500
# max     302.080000   586.270000   134.850000   292.020000   246.030000
#
#                 CO          SO2           O3      Benzene      Toluene  \
# count  1870.000000  1870.000000  1833.000000  1850.000000  1850.000000
# mean     12.628797    37.579032    38.580764     3.644962    19.800914
# std      19.437003    37.400898    21.447708     7.283405    26.530254
# ...

# %%
df.duplicated(subset=None , keep = 'first')
# Out:
# 1098    False
# 1099    False
# 1100    False
# 1101    False
# 1102    False
#         ...
# 3068    False
# 3069    False
# 3070    False
# 3071    False
# 3072    False
# Length: 1975, dtype: bool

# %%
df.isnull().sum()
# Out:
# City         0
# Date         0
# PM2.5       70
# PM10       560
# NO          63
# NO2         63
# NOx         59
# CO         105
# SO2        105
# O3         142
# Benzene    125
# Toluene    125
# Xylene     418
# AQI        140
# dtype: int64

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
def find_outliers_IQR(df):
   q1=df.quantile(0.25)
   q3=df.quantile(0.75)
   IQR=q3-q1
   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
   return outliers

# %%
outliers = find_outliers_IQR(df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]])
print("number of outliers:" + str(len(outliers)))
print("max outlier value:" + str(outliers.max()))
print("min outlier value:" + str(outliers.min()))
outliers
# Out:
# number of outliers:1975
# max outlier value:PM2.5       302.08
# PM10        586.27
# NO          134.85
# NO2         292.02
# NOx         246.03
# CO          134.85
# SO2         186.08
# O3          162.43
# Benzene     115.14
# Toluene     371.65
# Xylene      137.45
# AQI        2049.00
# dtype: float64
# min outlier value:PM2.5      137.81
# PM10       225.75
# NO          47.49
# NO2        152.96
# NOx        107.05
# CO          51.70
# SO2        114.51
# O3          90.23
# Benzene     10.25
# Toluene     80.04
# Xylene       7.98
# AQI        988.00
# dtype: float64
#       PM2.5  PM10  NO     NO2  NOx  CO  SO2      O3  Benzene  Toluene  Xylene  \
# 1098    NaN   NaN NaN     NaN  NaN NaN  NaN  105.33    12.77      NaN    9.50
# 1099    NaN   NaN NaN     NaN  NaN NaN  NaN     NaN    19.56      NaN   11.29
# 1100    NaN   NaN NaN  173.08  NaN NaN  NaN     NaN    17.69      NaN    9.93
# 1101    NaN   NaN NaN     NaN  NaN NaN  NaN     NaN    21.18      NaN   11.11
# ...

# %%
def drop_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   not_outliers = df[~((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   outliers_dropped = outliers.dropna().reset_index()

   return outliers_dropped

# %%
upper_limit = df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]].mean() + 3*df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]].std()

print(upper_limit)

lower_limit = df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]].mean() - 3*df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]].std()

print(lower_limit)
# Out:
# PM2.5       149.417796
# PM10        231.321001
# NO           69.274643
# NO2         184.153712
# NOx         130.773941
# CO           70.939807
# SO2         149.781725
# O3          102.923889
# Benzene      25.495177
# Toluene      99.391677
# Xylene       28.392552
# AQI        1219.815018
# dtype: float64
# PM2.5      -52.058100
# PM10       -65.000732
# NO         -39.553032
# NO2        -91.087279
# NOx        -63.995319
# CO         -45.682213
# SO2        -74.623661
# O3         -25.762361
# Benzene    -18.205252
# Toluene    -59.789850
# Xylene     -22.007992
# AQI       -642.180140
# dtype: float64

# %%
df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]] = np.where(df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]] > upper_limit,

   upper_limit,

   np.where(

       df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]] < lower_limit,

       lower_limit,

       df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]]

   )

)
# Out:
# C:\Users\Nagendra Swamy\anaconda3\lib\site-packages\pandas\core\frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
def impute_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   upper = df[~(df>(q3+1.5*IQR))].max()

   lower = df[~(df<(q1-1.5*IQR))].min()

   df = np.where(df > upper,

       df.mean(),

       np.where(

           df < lower,

           df.mean(),

           df

           )

       )

   return df

# %%
df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]]=impute_outliers_IQR(df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]])

# %%
df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]].describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1905.000000  1415.000000  1912.000000  1912.000000  1916.000000
# mean     46.812928    82.039355    11.798975    40.948694    29.134578
# std      29.417724    45.968785    11.177814    35.594339    23.871305
# min       0.160000     1.150000     0.250000     0.050000     0.000000
# 25%      22.900000    44.090000     3.087500    13.107500    10.392500
# 50%      40.980000    76.610000     7.095000    28.270000    20.110000
# 75%      66.210000   114.815000    16.310000    61.635000    43.712500
# max     133.480000   219.840000    47.440000   152.620000   106.350000
#
#                 CO          SO2           O3      Benzene      Toluene  \
# count  1870.000000  1870.000000  1833.000000  1850.000000  1850.000000
# mean      9.754600    31.066016    36.920511     2.141666    16.032889
# std      13.045181    26.171219    18.157042     2.370685    17.511628
# ...

# %%
df1 = df[["PM2.5", "PM10", "NO", "NO2", "NOx", "CO", "SO2", "O3", "Benzene", "Toluene", "Xylene", "AQI"]]

# %%
df = df.fillna(df1.mean())

# %%
df.isnull().sum()
# Out:
# City       0
# Date       0
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  1975.000000  1975.000000  1975.000000  1975.000000  1975.000000
# mean     46.812928    82.039355    11.798975    40.948694    29.134578
# std      28.891425    38.905783    10.997998    35.021738    23.511859
# min       0.160000     1.150000     0.250000     0.050000     0.000000
# 25%      23.705000    56.550000     3.175000    13.425000    10.565000
# 50%      42.270000    82.039355     7.520000    30.450000    20.970000
# 75%      64.515000    98.950000    15.575000    60.405000    43.045000
# max     133.480000   219.840000    47.440000   152.620000   106.350000
#
#                 CO          SO2           O3      Benzene      Toluene  \
# count  1975.000000  1975.000000  1975.000000  1975.000000  1975.000000
# mean      9.754600    31.066016    36.920511     2.141666    16.032889
# std      12.693494    25.465665    17.491790     2.294398    16.948115
# ...

# %%
df2 = df.fillna(df1.median())

# %%
df2
# Out:
#            City       Date  PM2.5       PM10     NO         NO2     NOx  \
# 1098  Ahmedabad   1/3/2018  63.88  82.039355  13.87   69.320000   44.16
# 1099  Ahmedabad   1/4/2018  81.10  82.039355  19.42  109.070000   67.15
# 1100  Ahmedabad   1/5/2018  73.61  82.039355  25.96   46.049141  103.80
# 1101  Ahmedabad   1/6/2018  75.79  82.039355  31.55  146.800000   95.16
# 1102  Ahmedabad   1/7/2018  77.87  82.039355  23.19  137.620000   84.44
# ...         ...        ...    ...        ...    ...         ...     ...
# 3068  Amaravati  6/27/2020  14.50  24.430000   1.53    6.530000    4.72
# 3069  Amaravati  6/28/2020  16.65  28.510000   1.43    8.320000    5.59
# 3070  Amaravati  6/29/2020  20.96  32.560000   1.65    9.550000    6.43
# 3071  Amaravati  6/30/2020  21.34  35.160000   1.74   10.690000    7.10
# 3072  Amaravati   7/1/2020  22.00  34.000000   1.50    9.680000    6.40
#
#          CO     SO2         O3   Benzene  Toluene    Xylene    AQI
# ...

# %%
df3 = df.fillna(df1.mode())

# %%
df3
# Out:
#            City       Date  PM2.5       PM10     NO         NO2     NOx  \
# 1098  Ahmedabad   1/3/2018  63.88  82.039355  13.87   69.320000   44.16
# 1099  Ahmedabad   1/4/2018  81.10  82.039355  19.42  109.070000   67.15
# 1100  Ahmedabad   1/5/2018  73.61  82.039355  25.96   46.049141  103.80
# 1101  Ahmedabad   1/6/2018  75.79  82.039355  31.55  146.800000   95.16
# 1102  Ahmedabad   1/7/2018  77.87  82.039355  23.19  137.620000   84.44
# ...         ...        ...    ...        ...    ...         ...     ...
# 3068  Amaravati  6/27/2020  14.50  24.430000   1.53    6.530000    4.72
# 3069  Amaravati  6/28/2020  16.65  28.510000   1.43    8.320000    5.59
# 3070  Amaravati  6/29/2020  20.96  32.560000   1.65    9.550000    6.43
# 3071  Amaravati  6/30/2020  21.34  35.160000   1.74   10.690000    7.10
# 3072  Amaravati   7/1/2020  22.00  34.000000   1.50    9.680000    6.40
#
#          CO     SO2         O3   Benzene  Toluene    Xylene    AQI
# ...

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
city_label = df.City.value_counts().nlargest(10)

''' barplot '''
plt.figure(figsize=(10, 5))
plt.xticks(rotation=75)
sns.barplot(city_label.index, city_label)
plt.xlabel('City', fontsize=20)
plt.ylabel('Count', fontsize=20);
# Out:
# C:\Users\Nagendra Swamy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Create the plot
sns.boxplot(x='City', y='AQI', hue='City', data=df)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 8))

mask = np.triu(df.corr(method='pearson'))
sns.heatmap(df.corr(method='pearson'),
                 annot=True, fmt='0.1f',
                 mask=mask,
                 robust=True,
                 cmap='pink')
plt.title('Correlation Analysis', fontsize=18);
plt.show()

# %%
# Group the data by city and calculate the mean PM2.5 value
city_pm25 = df.groupby('City')['PM2.5'].mean()

# Define labels, sizes, and colors for the pie chart
labels = list(city_pm25.index)
sizes = list(city_pm25.values)
colors = ['red', 'orange', 'green']

# Create a pie chart with colors
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add annotations to the chart
for i, label in enumerate(labels):
    angle = (sizes[i]/sum(sizes)) * 360
    ax1.annotate(label, xy=(0, 0), xytext=(1.2*np.cos(np.radians(90-angle/2)), 1.2*np.sin(np.radians(90-angle/2))), fontsize=0, ha='center', va='center', rotation=-(90-angle/2), bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# Add a title to the chart
plt.title('PM2.5 values of different cities')

# Display the chart
plt.show()

# %%
# Group the data by city and calculate the mean PM2.5 value
city_pm10 = df.groupby('City')['PM10'].mean()

# Define labels, sizes, and colors for the pie chart
labels = list(city_pm10.index)
sizes = list(city_pm10.values)
colors = ['blue', 'black', 'yellow']

# Create a pie chart with colors
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add annotations to the chart
for i, label in enumerate(labels):
    angle = (sizes[i]/sum(sizes)) * 360
    ax1.annotate(label, xy=(0, 0), xytext=(1.2*np.cos(np.radians(90-angle/2)), 1.2*np.sin(np.radians(90-angle/2))), fontsize=0, ha='center', va='center', rotation=-(90-angle/2), bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

# Add a title to the chart
plt.title('PM10 values of different cities')

# Display the chart
plt.show()
